# %%
import mitosheet
import pandas as pd

# Load your PMTCT dataset
df = pd.read_csv('uploads/DATA_SET_WITH_TRACE_OF_THE_MOTHER.csv')

# Launch the Mito spreadsheet
mitosheet.sheet(df)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[1], line 8
#       5 df = pd.read_csv('uploads/DATA_SET_WITH_TRACE_OF_THE_MOTHER.csv')
#       7 # Launch the Mito spreadsheet
# ----> 8 mitosheet.sheet(df)
#
# File ~/PYTHON_PROJECTS/PMTCT LONGITUDINAL DATA/.venv/lib/python3.12/site-packages/mitosheet/mito_backend.py:421, in sheet(analysis_to_replay, sheet_functions, importers, editors, input_cell_execution_count, *args)
#     419 if is_in_vs_code() or is_in_google_colab():
#     420     log('mitosheet_sheet_call_location_failed', failed=True)
# --> 421     raise Exception("The mitosheet currently only works in JupyterLab.\n\nTo see instructions on getting Mitosheet running in JupyterLab, find install instructions here: https://docs.trymito.io/getting-started/installing-mito")
#     422 elif is_dash():
# ...
